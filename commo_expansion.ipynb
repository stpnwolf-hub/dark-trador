# %% [markdown]
# <a href="https://colab.research.google.com/github/stpnwolf-hub/dark-trador/blob/main/commo_expansion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ALL Criterion HEATMAP

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define the data for the heatmap
data = {
    "Commodity": ["Beef", "Pork", "Vegetal Protein", "Cod", "Potato", "Paper Pulp", "Milk", "Olive Oil", "Copper",
                  "Lead", "Zinc", "Rare Earths", "Cobalt", "Nickel", "Steel", "Steel Scrap", "Temperature Derivatives",
                  "Rain Derivatives", "Container Freight", "Bulk Freight", "Salt", "Jet Fuel", "Sugar"],
    "Market Size": [5, 5, 3, 4, 4, 6, 5, 5, 8, 6, 7, 9, 8, 8, 9, 8, 5, 5, 7, 6, 5, 7, 6],
    "Value Chain Integration": [6, 7, 5, 6, 6, 8, 7, 7, 9, 7, 8, 9, 8, 8, 9, 7, 5, 5, 7, 6, 5, 8, 7],
    "Price Volatility": [3, 4, 6, 3, 2, 5, 3, 5, 7, 6, 7, 8, 8, 7, 6, 5, 4, 4, 6, 5, 3, 7, 5],
    "Price Correlation": [4, 4, 5, 4, 3, 6, 4, 5, 7, 6, 7, 8, 8, 7, 7, 6, 5, 5, 6, 5, 4, 7, 5]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Set the index to 'Commodity' for better heatmap labeling
df.set_index('Commodity', inplace=True)

# Generate the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df, annot=True, cmap="coolwarm", linewidths=.5)

# Show the plot
plt.title("Heatmap of Market Parameters for Various Commodities")
plt.show()

# %% [markdown]
# Value Chain Integration

# %%
import plotly.graph_objects as go

# Define a function to generate the sunburst chart
def create_sunburst(labels, parents, title):
    fig = go.Figure(go.Sunburst(
        labels=labels,
        parents=parents,
        maxdepth=4
    ))

    fig.update_layout(margin=dict(t=0, l=0, r=0, b=0), title=title)
    fig.show()

# Example Data for multiple commodities
value_chains = {
    "Beef": {
        "labels": ["Beef", "Farming", "Processing", "Distribution", "Retail",
                   "Cattle", "Slaughtering", "Packaging", "Wholesalers", "Retailers"],
        "parents": ["", "Beef", "Beef", "Beef", "Beef",
                    "Farming", "Processing", "Processing", "Distribution", "Distribution"]
    },
    "Pork": {
        "labels": ["Pork", "Breeding", "Farming", "Processing", "Distribution", "Retail",
                   "Piglets", "Pig Rearing", "Slaughtering", "Packaging", "Wholesalers", "Retailers"],
        "parents": ["", "Pork", "Pork", "Pork", "Pork", "Pork",
                    "Breeding", "Farming", "Processing", "Processing", "Distribution", "Distribution"]
    },
    "Vegetal Protein": {
        "labels": ["Vegetal Protein", "Farming", "Processing", "Distribution", "Retail",
                   "Soybeans", "Peas", "Protein Extraction", "Wholesalers", "Retailers"],
        "parents": ["", "Vegetal Protein", "Vegetal Protein", "Vegetal Protein", "Vegetal Protein",
                    "Farming", "Farming", "Processing", "Distribution", "Distribution"]
    },
    "Cod": {
        "labels": ["Cod", "Fishing", "Processing", "Distribution", "Retail",
                   "Catch", "Filleting", "Freezing", "Wholesalers", "Retailers"],
        "parents": ["", "Cod", "Cod", "Cod", "Cod",
                    "Fishing", "Processing", "Processing", "Distribution", "Distribution"]
    },
    "Potato": {
    "labels": ["Potato", "Farming", "Processing", "Distribution", "Retail",
               "Potato Farming", "Washing", "Peeling", "Wholesalers", "Retailers"],
    "parents": ["", "Potato", "Potato", "Potato", "Potato",
                "Farming", "Processing", "Processing", "Distribution", "Distribution"]
    },
    "Copper": {
    "labels": ["Copper", "Mining", "Smelting", "Refining", "Manufacturing", "Distribution",
               "Ore Extraction", "Concentrate Production", "Copper Cathode", "Wire Manufacturing", "Wholesalers"],
    "parents": ["", "Copper", "Copper", "Copper", "Copper", "Copper",
                "Mining", "Smelting", "Refining", "Manufacturing", "Distribution"]
},

    "Steel": {
        "labels": ["Steel", "Mining", "Smelting", "Refining", "Manufacturing", "Distribution",
                  "Ore Extraction", "Pig Iron Production", "Steelmaking", "Rolling & Finishing", "Wholesalers"],
        "parents": ["", "Steel", "Steel", "Steel", "Steel", "Steel",
                    "Mining", "Smelting", "Refining", "Manufacturing", "Distribution"]
    },

    "Scrap": {
        "labels": ["Scrap", "Collection", "Sorting", "Processing", "Manufacturing", "Distribution",
                  "Scrap Yards", "Material Recovery", "Recycling Plants", "Secondary Steelmaking", "Wholesalers"],
        "parents": ["", "Scrap", "Scrap", "Scrap", "Scrap", "Scrap",
                    "Collection", "Sorting", "Processing", "Manufacturing", "Distribution"]
    },
    "Temperature Derivatives": {
    "labels": ["Temperature Derivatives", "Weather Data Collection", "Index Construction", "Product Design", "Trading", "Settlement",
               "Meteorological Services", "Index Providers", "Financial Institutions", "Exchanges", "Clearing Houses"],
    "parents": ["", "Temperature Derivatives", "Temperature Derivatives", "Temperature Derivatives", "Temperature Derivatives", "Temperature Derivatives",
                "Weather Data Collection", "Index Construction", "Product Design", "Trading", "Settlement"]
},

"Rain Derivatives": {
    "labels": ["Rain Derivatives", "Weather Data Collection", "Index Construction", "Product Design", "Trading", "Settlement",
               "Meteorological Services", "Index Providers", "Financial Institutions", "Exchanges", "Clearing Houses"],
    "parents": ["", "Rain Derivatives", "Rain Derivatives", "Rain Derivatives", "Rain Derivatives", "Rain Derivatives",
                "Weather Data Collection", "Index Construction", "Product Design", "Trading", "Settlement"]
},
    "Bulk Freight": {
    "labels": ["Bulk Freight", "Cargo Owners", "Shipping Companies", "Port Operations", "Freight Forwarders", "Chartering",
               "Bulk Cargo Loading", "Sea Transport", "Bulk Cargo Unloading", "Storage", "End Distribution"],
    "parents": ["", "Bulk Freight", "Bulk Freight", "Bulk Freight", "Bulk Freight", "Bulk Freight",
                "Cargo Owners", "Shipping Companies", "Port Operations", "Port Operations", "Freight Forwarders"]
},

"Container Freight": {
    "labels": ["Container Freight", "Cargo Owners", "Shipping Companies", "Port Operations", "Freight Forwarders", "Container Leasing",
               "Container Loading", "Sea Transport", "Container Unloading", "Customs Clearance", "End Distribution"],
    "parents": ["", "Container Freight", "Container Freight", "Container Freight", "Container Freight", "Container Freight",
                "Cargo Owners", "Shipping Companies", "Port Operations", "Port Operations", "Freight Forwarders"]
},
    "Salt": {
    "labels": ["Salt", "Mining/Extraction", "Processing", "Refining", "Packaging", "Distribution",
               "Raw Salt Extraction", "Salt Processing", "Refined Salt", "Packaged Salt", "Wholesalers", "Retailers"],
    "parents": ["", "Salt", "Salt", "Salt", "Salt", "Salt",
                "Mining/Extraction", "Processing", "Refining", "Packaging", "Distribution", "Distribution"]
},

"Jet Fuel": {
    "labels": ["Jet Fuel", "Crude Oil Extraction", "Refining", "Blending", "Storage", "Distribution",
               "Crude Oil", "Kerosene Refining", "Jet A-1 Fuel", "Fuel Storage", "Aviation Fuel Distribution", "Airlines"],
    "parents": ["", "Jet Fuel", "Jet Fuel", "Jet Fuel", "Jet Fuel", "Jet Fuel",
                "Crude Oil Extraction", "Refining", "Blending", "Storage", "Distribution", "Distribution"]
},

"Beetroot Sugar": {
    "labels": ["Beetroot Sugar", "Cultivation", "Harvesting", "Processing", "Refining", "Packaging", "Distribution",
               "Beetroot Farming", "Sugar Beet Harvest", "Raw Sugar Production", "Refined Sugar", "Packaged Sugar", "Wholesalers", "Retailers"],
    "parents": ["", "Beetroot Sugar", "Beetroot Sugar", "Beetroot Sugar", "Beetroot Sugar", "Beetroot Sugar", "Beetroot Sugar",
                "Cultivation", "Harvesting", "Processing", "Refining", "Packaging", "Distribution", "Distribution"]
},



    # Add other commodities here in the same format...
}

# Generate sunburst charts for all commodities
for commodity, data in value_chains.items():
    create_sunburst(data['labels'], data['parents'], commodity)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Price Correlation and Vol

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Example Volatility Data (replace with actual data)
volatility_data = {
    "Commodity": ["Beef", "Pork", "Vegetal Protein", "Cod", "Potato", "Paper Pulp", "Milk", "Olive Oil", "Copper", "Lead"],
    "Volatility": [0.12, 0.15, 0.09, 0.11, 0.13, 0.14, 0.16, 0.08, 0.10, 0.07]
}

df = pd.DataFrame(volatility_data)

# Create the boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x="Commodity", y="Volatility", data=df)
plt.title('Commodity Price Volatility Box Plot')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 1. **Beef**
#    - **Market Size**: The European beef market is large, but consumption is stabilizing.
#    - **Trade Figures**: Significant intra-EU trade; limited global exports due to high standards and tariffs.
#    - **Concentration**: Fragmented market with various producers, no dominant players.
#    - **Price Volatility**: Moderate; influenced by feed prices, disease outbreaks, and trade policies.
#    - **Price Correlation**: Correlates with feed costs (corn, soybeans).
#    - **Conclusion**: Moderate potential for a futures contract; price volatility could support hedging needs, but market fragmentation and limited export activity might limit liquidity.
#
# ### 2. **Pork**
#    - **Market Size**: Large, with high consumption and production in the EU.
#    - **Trade Figures**: Significant intra-EU trade and exports to Asia.
#    - **Concentration**: More concentrated than beef, with some major integrated players.
#    - **Price Volatility**: High; driven by disease outbreaks (e.g., ASF) and export demand.
#    - **Price Correlation**: Strong correlation with feed prices and other protein sources.
#    - **Conclusion**: High potential for a futures contract due to significant market size, high volatility, and global trade importance.
#
# ### 3. **Vegetal Protein**
#    - **Market Size**: Growing rapidly due to the shift towards plant-based diets.
#    - **Trade Figures**: Increasing imports of soy and other plant proteins; intra-EU trade is developing.
#    - **Concentration**: Market is fragmented, with various small to medium players.
#    - **Price Volatility**: Moderate, influenced by agricultural commodity prices and demand shifts.
#    - **Price Correlation**: Correlates with soy, pea, and other agricultural products.
#    - **Conclusion**: Emerging market with potential; worth considering, especially as a niche or specialized contract.
#
# ### 4. **Cod**
#    - **Market Size**: Medium; significant consumer demand in Northern Europe.
#    - **Trade Figures**: Heavy reliance on imports, particularly from Norway and Iceland.
#    - **Concentration**: Moderate concentration in processing, dominated by a few key players.
#    - **Price Volatility**: Moderate; influenced by quotas, fishing conditions, and global demand.
#    - **Price Correlation**: Correlates with other seafood products and feed costs.
#    - **Conclusion**: Niche market; potential for a specialized contract but limited by reliance on imports and market size.
#
# ### 5. **Potato**
#    - **Market Size**: Significant in the EU, especially for processed products (e.g., fries).
#    - **Trade Figures**: Primarily intra-EU trade; limited global exports.
#    - **Concentration**: Fragmented market with many small to medium producers.
#    - **Price Volatility**: High; influenced by weather conditions and storage costs.
#    - **Price Correlation**: Limited; some correlation with agricultural input costs.
#    - **Conclusion**: High potential for a futures contract, especially in processed potato markets; volatility supports hedging.
#
# ### 6. **Paper Pulp**
#    - **Market Size**: Large, driven by packaging and paper demand.
#    - **Trade Figures**: Significant intra-EU trade; imports from North America and Scandinavia.
#    - **Concentration**: Highly concentrated; dominated by a few large firms.
#    - **Price Volatility**: Moderate; influenced by energy costs and demand for paper products.
#    - **Price Correlation**: Correlates with energy prices and wood products.
#    - **Conclusion**: High potential for a futures contract due to market size, concentration, and trade dynamics.
#
# ### 7. **Milk**
#    - **Market Size**: Very large; the EU is a top producer.
#    - **Trade Figures**: Significant intra-EU trade; exports mainly in powdered form.
#    - **Concentration**: Moderate; cooperatives play a significant role.
#    - **Price Volatility**: High; driven by seasonality, feed prices, and global demand.
#    - **Price Correlation**: Correlates with feed prices and other dairy products.
#    - **Conclusion**: High potential; already has established futures contracts, but additional products (e.g., skimmed milk powder) could be explored.
#
# ### 8. **Olive Oil**
#    - **Market Size**: Large, especially in Southern Europe.
#    - **Trade Figures**: Significant intra-EU trade; some global exports.
#    - **Concentration**: Fragmented, but with some dominant players in Spain and Italy.
#    - **Price Volatility**: High; influenced by weather, yields, and global demand.
#    - **Price Correlation**: Limited correlation with other commodities.
#    - **Conclusion**: Moderate potential; volatility supports hedging, but market fragmentation could limit liquidity.
#
# ### 9. **Copper**
#    - **Market Size**: Large; essential for industrial applications.
#    - **Trade Figures**: Significant imports of raw materials; some exports of refined products.
#    - **Concentration**: Highly concentrated among a few major mining companies.
#    - **Price Volatility**: High; driven by industrial demand and global economic conditions.
#    - **Price Correlation**: Strong correlation with other base metals (e.g., zinc, nickel).
#    - **Conclusion**: High potential; already well-established futures market, but Euronext could explore niche products.
#
# ### 10. **Lead**
#    - **Market Size**: Medium; important for batteries.
#    - **Trade Figures**: Moderate imports and exports within Europe.
#    - **Concentration**: Moderately concentrated; a few large players dominate.
#    - **Price Volatility**: Moderate; influenced by recycling rates and battery demand.
#    - **Price Correlation**: Correlates with other base metals, especially zinc.
#    - **Conclusion**: Moderate potential; could serve as a complementary contract to existing base metals.
#
# ### 11. **Zinc**
#    - **Market Size**: Large; key for galvanizing steel.
#    - **Trade Figures**: Significant imports and exports.
#    - **Concentration**: Moderately concentrated with a few dominant players.
#    - **Price Volatility**: High; driven by industrial demand and supply disruptions.
#    - **Price Correlation**: Strong correlation with copper and lead.
#    - **Conclusion**: High potential; well-established market, but opportunities exist for specialized contracts.
#
# ### 12. **Rare Earths**
#    - **Market Size**: Small but strategically important.
#    - **Trade Figures**: Heavy reliance on imports, particularly from China.
#    - **Concentration**: Highly concentrated; few global suppliers.
#    - **Price Volatility**: Very high; influenced by geopolitical risks.
#    - **Price Correlation**: Limited due to unique market dynamics.
#    - **Conclusion**: High potential as a strategic product; could attract interest due to supply chain concerns, but liquidity may be an issue.
#
# ### 13. **Cobalt**
#    - **Market Size**: Small but critical for batteries.
#    - **Trade Figures**: Significant imports; Europe is a key processor.
#    - **Concentration**: Highly concentrated; dominated by a few major mining companies.
#    - **Price Volatility**: Very high; driven by battery demand and geopolitical risks.
#    - **Price Correlation**: Correlates with lithium and nickel.
#    - **Conclusion**: High potential due to strategic importance, but liquidity might be a concern.
#
# ### 14. **Nickel**
#    - **Market Size**: Medium; essential for stainless steel and batteries.
#    - **Trade Figures**: Significant imports; some processing in Europe.
#    - **Concentration**: Moderately concentrated; a few large players dominate.
#    - **Price Volatility**: High; driven by stainless steel demand and battery applications.
#    - **Price Correlation**: Strong correlation with stainless steel and cobalt.
#    - **Conclusion**: High potential; already has futures contracts, but additional niche products could be explored.
#
# ### 15. **Steel**
#    - **Market Size**: Very large; foundational for European industry.
#    - **Trade Figures**: Significant intra-EU trade; imports of raw materials and exports of finished products.
#    - **Concentration**: Moderately concentrated; dominated by a few large producers.
#    - **Price Volatility**: Moderate; influenced by demand in construction and manufacturing.
#    - **Price Correlation**: Correlates with iron ore, coal, and energy prices.
#    - **Conclusion**: High potential; existing contracts could be expanded or refined.
#
# ### 16. **Steel Scrap**
#    - **Market Size**: Large; critical for recycling and sustainability efforts.
#    - **Trade Figures**: Significant intra-EU trade; imports from and exports to non-EU countries.
#    - **Concentration**: Fragmented, but with a few dominant recycling firms.
#    - **Price Volatility**: High; influenced by demand for recycled steel and raw material prices.
#    - **Price Correlation**: Correlates with steel and energy prices.
#    - **Conclusion**: High potential for a futures contract, especially in the context of sustainability and circular economy trends.
#
# ### 17. **Temperature Derivatives**
#    - **Market Size**: Niche; used for weather-related risk management.
#    - **Trade Figures**: Not applicable.
#    - **Concentration**: Highly specialized market
#
#  with few participants.
#    - **Price Volatility**: Based on weather patterns, can be high.
#    - **Price Correlation**: Limited; depends on specific weather-related factors.
#    - **Conclusion**: Limited potential due to niche market size; best suited as a specialized financial product.
#
# ### 18. **Rain Derivatives**
#    - **Market Size**: Niche; similar to temperature derivatives.
#    - **Trade Figures**: Not applicable.
#    - **Concentration**: Highly specialized.
#    - **Price Volatility**: Highly variable, depending on weather conditions.
#    - **Price Correlation**: Limited.
#    - **Conclusion**: Similar to temperature derivatives; niche market with limited potential for a broader audience.
#
# ### 19. **Container Freight Market**
#    - **Market Size**: Large; critical for global trade, particularly post-COVID.
#    - **Trade Figures**: Significant intra-EU and global trade.
#    - **Concentration**: Highly concentrated among a few major shipping lines.
#    - **Price Volatility**: Very high; influenced by global supply chain disruptions.
#    - **Price Correlation**: Correlates with global trade volumes and fuel prices.
#    - **Conclusion**: High potential; strong demand for hedging instruments, especially after recent volatility.
#
# ### 20. **Bulk Freight Market**
#    - **Market Size**: Large; essential for raw material transportation.
#    - **Trade Figures**: Significant global trade.
#    - **Concentration**: Moderately concentrated; dominated by a few large shipping companies.
#    - **Price Volatility**: High; driven by global trade and fuel prices.
#    - **Price Correlation**: Correlates with global commodity demand and energy prices.
#    - **Conclusion**: High potential; existing futures contracts could be expanded or refined.
#
# ### 21. **Salt**
#    - **Market Size**: Medium; important for chemical industry and de-icing.
#    - **Trade Figures**: Moderate imports and exports within Europe.
#    - **Concentration**: Moderately concentrated; a few large producers dominate.
#    - **Price Volatility**: Low; stable demand with seasonal peaks.
#    - **Price Correlation**: Limited.
#    - **Conclusion**: Low potential due to low price volatility and market size.
#
# ### 22. **Jet Fuel**
#    - **Market Size**: Large; critical for the aviation industry.
#    - **Trade Figures**: Significant intra-EU trade and global imports.
#    - **Concentration**: Highly concentrated; dominated by a few major oil companies.
#    - **Price Volatility**: High; influenced by crude oil prices and aviation demand.
#    - **Price Correlation**: Strong correlation with crude oil and distillates.
#    - **Conclusion**: High potential; existing futures market is robust, but opportunities exist for regional contracts.
#
# ### 23. **Sugar**
#    - **Market Size**: Large; significant in food and beverage industry.
#    - **Trade Figures**: Significant intra-EU trade; imports from tropical regions.
#    - **Concentration**: Moderately concentrated; a few large producers dominate.
#    - **Price Volatility**: High; influenced by weather conditions and global demand.
#    - **Price Correlation**: Correlates with other agricultural commodities.
#    - **Conclusion**: High potential; existing contracts could be expanded, especially with a focus on the European market.
#
# ---
#
# - **High Potential for New Contracts**: **Pork, Copper, Paper Pulp, Nickel, Steel, Container Freight** - Due to large market size, high trade activity, price volatility, and existing demand for hedging.
# - **Moderate Potential**: **Beef, Vegetal Protein, Potatoes, Milk, Olive Oil, Zinc, Cobalt, Steel Scrap, Jet Fuel, Sugar** - These markets have notable size and volatility but may face challenges in market liquidity or fragmentation.
# - **Low Potential/Niche**: **Cod, Rare Earths, Temperature/Rain Derivatives, Salt** - These markets are either niche, highly fragmented, or have limited liquidity, making them riskier or less attractive for launching new futures contracts.

# %% [markdown]
# Vertical Integration

# %%
import plotly.graph_objects as go

# Copper value chain stages
labels = [
    "Copper", "Ore Extraction", "Concentrate Production", "Smelting", "Refining", "Manufacturing", "Distribution"
]

# Key actors in the copper industry and their control over each stage
# For example, let's assume these values are hypothetical percentages of market control
actors = [
    "Company A", "Company B", "Company C", "Company D", "Company E"
]

# Define sources and targets
source = [0, 0, 1, 2, 3, 4, 5]
target = [1, 2, 3, 4, 5, 6, 6]

# Define the actor involvement at each stage with hypothetical values
# These values represent the level of control or market share by each company at different stages
values = [30, 25, 20, 15, 10, 10, 20]  # These could represent market share percentages

# Add color coding for different companies (optional)
colors = ["#636EFA", "#EF553B", "#00CC96", "#AB63FA", "#FFA15A"]

# Create the Sankey diagram
fig = go.Figure(data=[go.Sankey(
    node=dict(
        pad=15,
        thickness=20,
        line=dict(color="black", width=0.5),
        label=labels + actors,  # Adding actors to the labels
        color=["blue", "blue", "blue", "blue", "blue", "blue", "blue"] + colors
    ),
    link=dict(
        source=source,
        target=[len(labels) + i for i in range(len(source))],  # Link to actors
        value=values
    )
)])

# Update the layout
fig.update_layout(title_text="Vertical Integration of Major Actors in Copper Value Chain", font_size=10)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt

# Sample data (replace with your actual data)
commodity_names = ['Beef','pork', 'Milk', 'pulp', 'olive', 'scrap', 'bulk', 'container', 'EBM','Sugar','copper','Nickel','Lead','Zinc','Jet Fuel']
market_sizes = [50,45, 30, 100, 20, 25, 40, 60, 35,20,40,9,4,10, 32]
volatilities = [0.17,0.4, 0.10, 0.07, 0.3, 0.6, 0.57, 0.4, 0.21,0.12,0.19,0.33,0.21,0.27,0.3]
colors = ["#41B6E6", "#79D100", "#009639", "#00685E"]

# Create the scatter plot
plt.figure(figsize=(10, 6))
for i in range(len(commodity_names)):
  plt.scatter(market_sizes[i], volatilities[i], color=colors[i % len(colors)], s=100)
  plt.text(market_sizes[i], volatilities[i] + 0.02, commodity_names[i], ha='center', va='bottom')

# Customize the plot
plt.title('Commodity Market Size vs. Volatility')
plt.xlabel('Market Size')
plt.ylabel('Volatility')
plt.grid(True)

# Add a legend
# You might need to adjust the legend position based on your data
# Create a legend based on your colors and labels
# legend_elements = [plt.Line2D([0], [0], marker='o', color='w', label='Commodity Name', markerfacecolor=colors[i], markersize=10) for i in range(len(colors))]
# plt.legend(handles=legend_elements)


plt.show()

# %% [markdown]
# 4D scatter

# %%
# prompt: Can you generate a 3d scatter plot that shows market sizes, volatility,  value chaine concentration, of several commodities. the plot must be redeable and use a color ay from blue to red , commodities name should be in front of  the dot of the scatter plot

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Sample data (replace with your actual data)
commodity_names = ['Beef', 'Pork', 'Milk', 'Pulp', 'Olive', 'Scrap', 'Bulk', 'Container', 'EBM', 'Sugar', 'Copper', 'Nickel', 'Lead', 'Zinc', 'Jet Fuel']
market_sizes = [50, 45, 30, 100, 20, 25, 40, 60, 35, 20, 40, 9, 4, 10, 32]
volatilities = [0.17, 0.4, 0.10, 0.07, 0.3, 0.6, 0.57, 0.4, 0.21, 0.12, 0.19, 0.33, 0.21, 0.27, 0.3]
concentrations = [6,6,5,4,9,4,9,4,7,7,7,8,7,4,3,3,4,5,5,5,7,8,5]  # Hypothetical concentration values

# Create a 3D scatter plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Define a colormap from blue to red
cmap = plt.cm.get_cmap('RdBu')

# Normalize the concentration data to map to the colormap
norm = plt.Normalize(min(concentrations), max(concentrations))

# Plot the data points with color based on concentration and labels
for i in range(len(commodity_names)):
    color = cmap(norm(concentrations[i]))
    ax.scatter(market_sizes[i], volatilities[i], concentrations[i], color=color, s=100)
    ax.text(market_sizes[i], volatilities[i], concentrations[i], commodity_names[i], fontsize=8)


# Customize the plot
ax.set_xlabel('Market Size')
ax.set_ylabel('Volatility')
ax.set_zlabel('Value Chain Concentration')
ax.set_title('Commodity Market Characteristics in 3D')

# Improve readability by adjusting view angle and labels
ax.view_init(elev=20, azim=30)  # Adjust elevation and azimuth for better viewing
plt.tight_layout()

plt.show()
# Out:
# <ipython-input-10-8a1fa51613f6>:18: MatplotlibDeprecationWarning:
#
# The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.

# %%
# prompt: generate a 3D scatter plot with plotly

import plotly.express as px

# Sample data (replace with your actual data)
commodity_names = ['Beef', 'Pork', 'Milk', 'Pulp', 'Olive', 'Scrap', 'Bulk', 'Container', 'EBM', 'Sugar', 'Copper', 'Nickel', 'Lead', 'Zinc', 'Jet Fuel']
market_sizes = [50, 45, 30, 100, 20, 25, 40, 60, 35, 20, 40, 9, 4, 10, 32]
volatilities = [0.17, 0.4, 0.10, 0.07, 0.3, 0.6, 0.57, 0.4, 0.21, 0.12, 0.19, 0.33, 0.21, 0.27, 0.3]
concentrations = [6, 6, 5, 4, 9, 4, 9, 4, 7, 7, 7, 8, 7, 4, 3]  # Hypothetical concentration values


# Create a 3D scatter plot with Plotly Express
fig = px.scatter_3d(
    x=market_sizes,
    y=volatilities,
    z=concentrations,
    hover_name=commodity_names,  # Show commodity names on hover
    labels={'x': 'Market Size', 'y': 'Volatility', 'z': 'Concentration'},
    title='Commodity Market Characteristics in 3D'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# prompt: generate a 3D scatter plot with plotly, show commodity names above the dots and use a blue to red colormap

import plotly.graph_objects as go
import numpy as np

# Sample data (replace with your actual data)
commodity_names = ['Beef', 'Pork', 'Milk', 'Pulp', 'Olive', 'Scrap', 'Bulk', 'Container', 'EBM', 'Sugar', 'Copper', 'Nickel', 'Lead', 'Zinc', 'Jet Fuel']
market_sizes = [50, 45, 30, 100, 20, 25, 40, 60, 35, 20, 40, 9, 4, 10, 32]
volatilities = [0.17, 0.4, 0.10, 0.07, 0.3, 0.6, 0.57, 0.4, 0.21, 0.12, 0.19, 0.33, 0.21, 0.27, 0.3]
concentrations = [6, 6, 5, 4, 9, 4, 9, 4, 7, 7, 7, 8, 7, 4, 3]  # Hypothetical concentration values


fig = go.Figure(data=[go.Scatter3d(
    x=market_sizes,
    y=volatilities,
    z=concentrations,
    mode='markers',
    marker=dict(
        size=8,
        color=concentrations,  # set color to an array/list of desired values
        colorscale='RdBu',  # choose a colorscale
        opacity=0.8
    ),
    text=commodity_names,  # Set the text for each point
    hoverinfo='text'  # Display only the text on hover
)])

fig.update_layout(
    title='Commodity Market Characteristics in 3D',
    scene=dict(
        xaxis_title='Market Size',
        yaxis_title='Volatility',
        zaxis_title='Concentration'
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
